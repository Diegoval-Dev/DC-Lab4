# %%
# === CONFIG GLOBAL ===
from pathlib import Path
import os

# Carpeta para resultados y descargas
DATA_DIR = Path("data"); DATA_DIR.mkdir(exist_ok=True)
IMG_DIR  = Path("imgs"); IMG_DIR.mkdir(exist_ok=True)

# Bandas que usaremos (incluye todas las necesarias para NDCI/FAI y máscaras)
BANDS_FULL = ["B02","B03","B04","B05","B07","B8A","B11","B12"]

# AOIs
LAKES = {
    "Atitlán":   {"west": -91.349, "east": -91.0702, "south": 14.5971, "north": 14.7648},
    "Amatitlán": {"west": -90.66,  "east": -90.58,   "south": 14.43,   "north": 14.51},
}

CSV_PATH = DATA_DIR / "chl_timeseries.csv"

# Umbrales (ajustables)
MNDWI_THR = 0.42
NDWI_THR  = 0.40
FAI_FLOATING_THR = 0.08
CHL_CLIP_UPPER = 500.0   # para evitar explosiones en la media

# %%
import numpy as np, pandas as pd, rasterio, glob
import openeo


def connect_openeo():
    return openeo.connect("https://openeo.dataspace.copernicus.eu").authenticate_oidc()


def download_s2_tif(conn, aoi, dates, title, out_dir=IMG_DIR, cloud_cover=20):
    """
    Descarga un GeoTIFF multibanda para la ventana 'dates'.
    Usa filtro de nubosidad si se especifica.
    Devuelve la ruta del último .tif descargado.
    """
    kwargs = dict(
    collection_id="SENTINEL2_L2A",
    spatial_extent=aoi,
    temporal_extent=dates,
    bands=BANDS_FULL
    )

    cube = conn.load_collection(**kwargs)
    graph = cube.save_result(format="GTIFF")
    job = conn.create_job(graph, title=title)
    job.start_and_wait()
    out_dir.mkdir(exist_ok=True)
    job.download_results(str(out_dir))
    tifs = sorted(out_dir.glob("*.tif"), key=lambda p: p.stat().st_mtime)
    if not tifs:
        raise RuntimeError("No se descargó ningún .tif. Prueba con otra ventana de fechas o mayor tolerancia de nubes.")
    return str(tifs[-1])


def load_bands(tif_path):
    with rasterio.open(tif_path) as src:
        data = src.read()
        nodata = src.nodata
    B02,B03,B04,B05,B07,B8A,B11,B12 = [data[i].astype("float32") for i in range(8)]
    return dict(B02=B02, B03=B03, B04=B04, B05=B05, B07=B07, B8A=B8A, B11=B11, B12=B12), nodata


def to_reflectance(b, nodata=None, scale=10000.0):
    out = b.astype("float32")
    if nodata is not None:
        out = np.where(b == nodata, np.nan, out)
    return out / scale


def scale_all(bands, nodata=None):
    return {k: to_reflectance(v, nodata=nodata) for k,v in bands.items()}


def water_mask(R):
    B02,B03,B04,B8A,B11,B12 = R["B02"],R["B03"],R["B04"],R["B8A"],R["B11"],R["B12"]
    ndwi  = (B03 - B8A) / (B03 + B8A + 1e-9)
    mndwi = (B03 - B11) / (B03 + B11 + 1e-9)
    aweish  = B02 + 2.5*B03 - 1.5*(B8A + B11) - 0.25*B12
    aweinsh = 4*(B03 - B11) - (0.25*B8A + 2.75*B11)
    ndvi = (B8A - B04) / (B8A + B04 + 1e-9)
    dbsi = ((B11 - B03) / (B11 + B03 + 1e-9)) - ndvi
    ws = ( (mndwi > MNDWI_THR) | (ndwi > NDWI_THR) | (aweinsh > 0.1879) | (aweish > 0.1112) | (ndvi < -0.2) )
    ws = ws & ~((aweinsh <= -0.03) | (dbsi > 0))
    return ws


def FAI(B04, B07, B8A):
    return (B07 - (B04 + (B8A - B04) * (783 - 665) / (865 - 665)))


def NDCI(B04, B05):
    return (B05 - B04) / (B05 + B04 + 1e-9)


def chl_exp(ndci):
    # Clip NDCI a rango razonable para evitar overflow
    ndci = np.clip(ndci, -1.0, 1.0)
    return 17.441 * np.exp(4.7038 * ndci)


def chlorophyll_map(R, mask_water, use_exp=True, exclude_floating=True):
    B04,B05,B07,B8A = R["B04"], R["B05"], R["B07"], R["B8A"]
    fai  = FAI(B04, B07, B8A)
    ndci = NDCI(B04, B05)
    chl  = chl_exp(ndci) if use_exp else (826.57*(ndci**3) - 176.43*(ndci**2) + 19*ndci + 4.071)
    chl  = np.where(mask_water, chl, np.nan)
    if exclude_floating:
        chl = np.where(fai > FAI_FLOATING_THR, np.nan, chl)
    # Anti-outliers
    chl = np.where(np.isfinite(chl), chl, np.nan)
    chl = np.where(chl > CHL_CLIP_UPPER, np.nan, chl)
    return chl


def summarize_chl(chl):
    arr = chl[np.isfinite(chl)]
    if arr.size == 0:
        return dict(mean=np.nan, median=np.nan, p25=np.nan, p75=np.nan, n=0)
    return dict(
        mean=float(arr.mean()),
        median=float(np.median(arr)),
        p25=float(np.percentile(arr,25)),
        p75=float(np.percentile(arr,75)),
        n=int(arr.size)
    )


def append_timeseries(csv_path, new_rows_df):
    try:
        hist = pd.read_csv(csv_path, parse_dates=["date"])
        out = pd.concat([hist, new_rows_df], ignore_index=True)
    except FileNotFoundError:
        out = new_rows_df.copy()

    out = (out
           .drop_duplicates(subset=["lake","date"], keep="last")
           .sort_values(["lake","date"]))

    tmp = csv_path.with_suffix(".tmp.csv")
    out.to_csv(tmp, index=False, encoding="utf-8")
    os.replace(tmp, csv_path)  # escritura atómica
    return out


def clean_tiffs(folder=IMG_DIR, pattern="*.tif"):
    for p in Path(folder).glob(pattern):
        try:
            p.unlink()
        except Exception as e:
            print("No se pudo borrar", p, e)


def process_week_for_lake(conn, lake_name, aoi, date_window, scene_date, cloud_cover=20):
    """
    pipeline: descarga -> bandas -> reflectancia -> máscara -> clorofila -> resumen
    Devuelve dict con stats y también hace limpieza de TIFFs.
    """
    title = f"S2 {lake_name} all bands {date_window[0]}..{date_window[1]}"
    tif_path = download_s2_tif(conn, aoi, date_window, title=title, cloud_cover=cloud_cover)

    bands, nodata = load_bands(tif_path)
    R = scale_all(bands, nodata=nodata)
    water = water_mask(R)
    chl = chlorophyll_map(R, water, use_exp=True, exclude_floating=True)
    stats = summarize_chl(chl)

    # armar fila
    row = {
        "date": pd.to_datetime(scene_date),
        "lake": lake_name,
        "chl_mean":  stats["mean"],
        "chl_median":stats["median"],
        "chl_p25":   stats["p25"],
        "chl_p75":   stats["p75"],
    }

    # limpia para no llenar disco
    clean_tiffs()
    return row

# %%
import sys, platform
import numpy as np, pandas as pd, matplotlib
import rasterio, statsmodels

print("Python:", sys.version.split()[0])
print("OS:", platform.platform())
print("numpy:", np.__version__)
print("pandas:", pd.__version__)
print("matplotlib:", matplotlib.__version__)
print("rasterio:", rasterio.__version__)
import statsmodels.api as sm
print("statsmodels:", sm.__version__)
# Out:
# Python: 3.10.2
# OS: macOS-15.5-arm64-arm-64bit
# numpy: 2.2.6
# pandas: 2.3.1
# matplotlib: 3.10.5
# rasterio: 1.4.3
# statsmodels: 0.14.5

# %%
#!pip install -q openeo rasterio numpy pandas matplotlib

# %%
# === CAMBIA ESTAS DOS LINEAS CADA SEMANA ===
fechas_semana_atitlan   = ["2025-02-11", "2025-02-15"]  # ventana corta
fecha_escena_atitlan    = "2025-02-13"                  # fecha real elegida

fechas_semana_amatitlan = ["2025-02-16", "2025-02-20"]
fecha_escena_amatitlan  = "2025-02-18"

# -------------------------------------------
conn = connect_openeo()

rows = []
rows.append(
    process_week_for_lake(conn, "Atitlán",   LAKES["Atitlán"],   fechas_semana_atitlan,   fecha_escena_atitlan,   cloud_cover=20)
)
rows.append(
    process_week_for_lake(conn, "Amatitlán", LAKES["Amatitlán"], fechas_semana_amatitlan, fecha_escena_amatitlan, cloud_cover=20)
)

df_new = pd.DataFrame(rows)
df_out = append_timeseries(CSV_PATH, df_new)
print("Actualizado:", CSV_PATH, "→ total filas:", len(df_out))
display(df_new)
# Out:
# Authenticated using refresh token.
# 0:00:00 Job 'j-25081420322348e9a1de4b1e161dfc79': send 'start'
# 0:00:13 Job 'j-25081420322348e9a1de4b1e161dfc79': created (progress 0%)
# 0:00:19 Job 'j-25081420322348e9a1de4b1e161dfc79': created (progress 0%)
# 0:00:25 Job 'j-25081420322348e9a1de4b1e161dfc79': created (progress 0%)
# 0:00:34 Job 'j-25081420322348e9a1de4b1e161dfc79': created (progress 0%)
# 0:00:44 Job 'j-25081420322348e9a1de4b1e161dfc79': created (progress 0%)
# 0:00:56 Job 'j-25081420322348e9a1de4b1e161dfc79': running (progress N/A)
# 0:01:12 Job 'j-25081420322348e9a1de4b1e161dfc79': running (progress N/A)
# 0:01:32 Job 'j-25081420322348e9a1de4b1e161dfc79': running (progress N/A)
# 0:01:56 Job 'j-25081420322348e9a1de4b1e161dfc79': finished (progress 100%)
# /var/folders/kd/4y1c0b3j1273_pm_gb0hfhdw0000gn/T/ipykernel_25750/2224465159.py:27: UserDeprecationWarning: Call to deprecated method download_results. (Instead use `BatchJob.get_results` and the more flexible download functionality of `JobResults`) -- Deprecated since version 0.4.10.
#   job.download_results(str(out_dir))
# /Users/gerco/UVG/8th_semester/Data_Science/DC-Lab4/venv/lib/python3.10/site-packages/openeo/rest/job.py:199: UserDeprecationWarning: Call to deprecated method get_result. (Use `BatchJob.get_results` instead.) -- Deprecated since version 0.4.10.
#   return self.get_result().download_files(target)
# /Users/gerco/UVG/8th_semester/Data_Science/DC-Lab4/venv/lib/python3.10/site-packages/openeo/rest/job.py:203: UserDeprecationWarning: Call to deprecated class _Result. (Use `JobResults` instead) -- Deprecated since version 0.4.10.
#   return _Result(self)
# 0:00:00 Job 'j-2508142036274e9590e07ebf560254f2': send 'start'
# 0:00:13 Job 'j-2508142036274e9590e07ebf560254f2': created (progress 0%)
# 0:00:19 Job 'j-2508142036274e9590e07ebf560254f2': created (progress 0%)
# 0:00:25 Job 'j-2508142036274e9590e07ebf560254f2': created (progress 0%)
# 0:00:33 Job 'j-2508142036274e9590e07ebf560254f2': created (progress 0%)
# 0:00:44 Job 'j-2508142036274e9590e07ebf560254f2': running (progress N/A)
# 0:00:56 Job 'j-2508142036274e9590e07ebf560254f2': running (progress N/A)
# 0:01:12 Job 'j-2508142036274e9590e07ebf560254f2': running (progress N/A)
# 0:01:31 Job 'j-2508142036274e9590e07ebf560254f2': running (progress N/A)
# 0:01:55 Job 'j-2508142036274e9590e07ebf560254f2': finished (progress 100%)
# Actualizado: data/chl_timeseries.csv → total filas: 2
#         date       lake   chl_mean  chl_median    chl_p25   chl_p75
# 0 2025-02-13    Atitlán  15.209627   14.985576  12.875841  17.82654
# 1 2025-02-18  Amatitlán  21.114990   21.114395  20.754000  21.48053

# %%
# Entrenamiento rápido ARIMA cuando existan suficientes puntos
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

try:
    ts = pd.read_csv(CSV_PATH, parse_dates=["date"])
except FileNotFoundError:
    print("Aún no existe el CSV", CSV_PATH)
else:
    ORDER = (1,1,1)
    STEPS = 4
    MIN_PTS = 8

    for lake in ts["lake"].unique():
        df_lake = (ts[ts["lake"]==lake]
                   .sort_values("date")
                   .set_index("date"))

        # semanal: por si las fechas no caen en el mismo día
        y = df_lake["chl_mean"].resample("7D").mean().interpolate(limit_direction="both")
        y = y.mask((~np.isfinite(y)) | (y <= 0)).dropna()

        if len(y) < MIN_PTS:
            print(f"[{lake}] pocos puntos ({len(y)}). Sigue agregando semanas.")
            continue

        res = ARIMA(y, order=ORDER).fit()
        print(f"[{lake}] AIC={res.aic:.2f} puntos={len(y)}")

        fc = res.get_forecast(steps=STEPS)
        mean_fc = fc.predicted_mean
        ci = fc.conf_int()
        future_idx = pd.date_range(start=y.index[-1] + pd.Timedelta(days=7), periods=STEPS, freq="7D")

        plt.figure(figsize=(8,4))
        plt.plot(y.index, y.values, marker="o", label="Observado")
        plt.plot(future_idx, mean_fc.values, marker="x", label="Pronóstico")
        plt.fill_between(future_idx, ci.iloc[:,0], ci.iloc[:,1], alpha=0.2)
        plt.title(f"Chl-a media · {lake}")
        plt.xlabel("Fecha"); plt.ylabel("mg/m³ aprox.")
        plt.grid(True, alpha=0.3); plt.legend()
        plt.show()
# Out:
# [Amatitlán] pocos puntos (1). Sigue agregando semanas.
# [Atitlán] pocos puntos (1). Sigue agregando semanas.

# %%
# === PROCESO POR FECHAS INDIVIDUALES (ventanas de 1 día) ===
# === LISTA DE FECHAS RECOMENDADAS (nubosidad ≤ 20%) ===
RECOMMENDED_DATES = [
    "2025-02-07","2025-02-10","2025-02-25","2025-02-27",
    "2025-03-02","2025-03-04","2025-03-07","2025-03-09","2025-03-12","2025-03-14",
    "2025-03-19","2025-03-22","2025-03-24","2025-03-26",
    "2025-04-03","2025-04-11","2025-04-13","2025-04-15","2025-04-16","2025-04-18",
    "2025-04-28","2025-05-03","2025-05-13","2025-05-28",
    "2025-07-10","2025-07-17","2025-07-20","2025-07-24","2025-08-01"
]

import pandas as pd

def day_window(d):
    d0 = pd.to_datetime(d)
    return [d0.strftime("%Y-%m-%d"), (d0 + pd.Timedelta(days=1)).strftime("%Y-%m-%d")]

# TIP: para procesar en tandas pequeñas, ajusta aquí
# DATES_BATCH = RECOMMENDED_DATES[:5]
DATES_BATCH = RECOMMENDED_DATES

conn = connect_openeo()
rows = []

for d in DATES_BATCH:
    win = day_window(d)

    # Atitlán
    try:
        rows.append(
            process_week_for_lake(
                conn,
                lake_name="Atitlán",
                aoi=LAKES["Atitlán"],
                date_window=win,
                scene_date=d,
                cloud_cover=20
            )
        )
        print(f"[OK] Atitlán {d}")
    except Exception as e:
        print(f"[SKIP] Atitlán {d} -> {e}")

    # Amatitlán
    try:
        rows.append(
            process_week_for_lake(
                conn,
                lake_name="Amatitlán",
                aoi=LAKES["Amatitlán"],
                date_window=win,
                scene_date=d,
                cloud_cover=20
            )
        )
        print(f"[OK] Amatitlán {d}")
    except Exception as e:
        print(f"[SKIP] Amatitlán {d} -> {e}")

# Append idempotente al CSV global
import numpy as np

df_new = pd.DataFrame(rows)
display(df_new)

df_out = append_timeseries(CSV_PATH, df_new)
print(f"Actualizado {CSV_PATH} → total filas: {len(df_out)}")
# Out:
# Authenticated using refresh token.
# 0:00:00 Job 'j-25081420390646c9b5d75aa6928c4fba': send 'start'
# 0:00:13 Job 'j-25081420390646c9b5d75aa6928c4fba': created (progress 0%)
# 0:00:19 Job 'j-25081420390646c9b5d75aa6928c4fba': created (progress 0%)
# 0:00:26 Job 'j-25081420390646c9b5d75aa6928c4fba': created (progress 0%)
# 0:00:34 Job 'j-25081420390646c9b5d75aa6928c4fba': created (progress 0%)
# 0:00:44 Job 'j-25081420390646c9b5d75aa6928c4fba': created (progress 0%)
# 0:00:57 Job 'j-25081420390646c9b5d75aa6928c4fba': created (progress 0%)
# 0:01:12 Job 'j-25081420390646c9b5d75aa6928c4fba': running (progress N/A)
# 0:01:32 Job 'j-25081420390646c9b5d75aa6928c4fba': running (progress N/A)
# 0:01:56 Job 'j-25081420390646c9b5d75aa6928c4fba': running (progress N/A)
# 0:02:26 Job 'j-25081420390646c9b5d75aa6928c4fba': finished (progress 100%)
# /var/folders/kd/4y1c0b3j1273_pm_gb0hfhdw0000gn/T/ipykernel_25750/2224465159.py:27: UserDeprecationWarning: Call to deprecated method download_results. (Instead use `BatchJob.get_results` and the more flexible download functionality of `JobResults`) -- Deprecated since version 0.4.10.
#   job.download_results(str(out_dir))
# /Users/gerco/UVG/8th_semester/Data_Science/DC-Lab4/venv/lib/python3.10/site-packages/openeo/rest/job.py:199: UserDeprecationWarning: Call to deprecated method get_result. (Use `BatchJob.get_results` instead.) -- Deprecated since version 0.4.10.
#   return self.get_result().download_files(target)
# /Users/gerco/UVG/8th_semester/Data_Science/DC-Lab4/venv/lib/python3.10/site-packages/openeo/rest/job.py:203: UserDeprecationWarning: Call to deprecated class _Result. (Use `JobResults` instead) -- Deprecated since version 0.4.10.
#   return _Result(self)
# [OK] Atitlán 2025-02-07
# 0:00:00 Job 'j-2508142044004acd855e435a3df06050': send 'start'
# 0:00:13 Job 'j-2508142044004acd855e435a3df06050': queued (progress 0%)
# 0:00:18 Job 'j-2508142044004acd855e435a3df06050': queued (progress 0%)
# 0:00:25 Job 'j-2508142044004acd855e435a3df06050': queued (progress 0%)
# 0:00:33 Job 'j-2508142044004acd855e435a3df06050': queued (progress 0%)
# 0:00:43 Job 'j-2508142044004acd855e435a3df06050': queued (progress 0%)
# 0:00:56 Job 'j-2508142044004acd855e435a3df06050': queued (progress 0%)
# 0:01:11 Job 'j-2508142044004acd855e435a3df06050': running (progress N/A)
# 0:01:31 Job 'j-2508142044004acd855e435a3df06050': running (progress N/A)
# 0:01:55 Job 'j-2508142044004acd855e435a3df06050': running (progress N/A)
# 0:02:25 Job 'j-2508142044004acd855e435a3df06050': finished (progress 100%)
# [OK] Amatitlán 2025-02-07
# 0:00:00 Job 'j-25081420464543fa89b9e260041c2273': send 'start'
# 0:00:13 Job 'j-25081420464543fa89b9e260041c2273': created (progress 0%)
# 0:00:19 Job 'j-25081420464543fa89b9e260041c2273': created (progress 0%)
# 0:00:25 Job 'j-25081420464543fa89b9e260041c2273': running (progress N/A)
# 0:00:34 Job 'j-25081420464543fa89b9e260041c2273': running (progress N/A)
# 0:00:45 Job 'j-25081420464543fa89b9e260041c2273': running (progress N/A)
# 0:00:57 Job 'j-25081420464543fa89b9e260041c2273': running (progress N/A)
# 0:01:13 Job 'j-25081420464543fa89b9e260041c2273': running (progress N/A)
# 0:01:32 Job 'j-25081420464543fa89b9e260041c2273': finished (progress 100%)
# [OK] Atitlán 2025-02-10
# 0:00:00 Job 'j-2508142049144b059ac9d8b3eeea532b': send 'start'
# 0:00:13 Job 'j-2508142049144b059ac9d8b3eeea532b': created (progress 0%)
# 0:00:18 Job 'j-2508142049144b059ac9d8b3eeea532b': created (progress 0%)
# 0:00:25 Job 'j-2508142049144b059ac9d8b3eeea532b': created (progress 0%)
# 0:00:33 Job 'j-2508142049144b059ac9d8b3eeea532b': created (progress 0%)
# 0:00:43 Job 'j-2508142049144b059ac9d8b3eeea532b': created (progress 0%)
# 0:00:56 Job 'j-2508142049144b059ac9d8b3eeea532b': created (progress 0%)
# 0:01:11 Job 'j-2508142049144b059ac9d8b3eeea532b': error (progress N/A)
# Your batch job 'j-2508142049144b059ac9d8b3eeea532b' failed. Error logs:
# [{'id': '[1755204592400, 429020]', 'time': '2025-08-14T20:49:52.400Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142049144b059ac9d8b3eeea532b" and returned 0 results.'}, {'id': '[1755204593008, 824322]', 'time': '2025-08-14T20:49:53.008Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142049144b059ac9d8b3eeea532b" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-2508142049144b059ac9d8b3eeea532b').logs()`.
# [SKIP] Amatitlán 2025-02-10 -> Batch job 'j-2508142049144b059ac9d8b3eeea532b' didn't finish successfully. Status: error (after 0:01:12).
# 0:00:00 Job 'j-2508142050274c2b9180524e77f7608a': send 'start'
# 0:00:13 Job 'j-2508142050274c2b9180524e77f7608a': created (progress 0%)
# 0:00:19 Job 'j-2508142050274c2b9180524e77f7608a': created (progress 0%)
# 0:00:25 Job 'j-2508142050274c2b9180524e77f7608a': created (progress 0%)
# 0:00:33 Job 'j-2508142050274c2b9180524e77f7608a': created (progress 0%)
# 0:00:44 Job 'j-2508142050274c2b9180524e77f7608a': running (progress N/A)
# 0:00:56 Job 'j-2508142050274c2b9180524e77f7608a': running (progress N/A)
# 0:01:12 Job 'j-2508142050274c2b9180524e77f7608a': running (progress N/A)
# 0:01:31 Job 'j-2508142050274c2b9180524e77f7608a': running (progress N/A)
# 0:01:56 Job 'j-2508142050274c2b9180524e77f7608a': finished (progress 100%)
# [OK] Atitlán 2025-02-25
# 0:00:00 Job 'j-2508142053284a7c8f61da9fa5d4d61e': send 'start'
# 0:00:13 Job 'j-2508142053284a7c8f61da9fa5d4d61e': created (progress 0%)
# 0:00:19 Job 'j-2508142053284a7c8f61da9fa5d4d61e': created (progress 0%)
# 0:00:25 Job 'j-2508142053284a7c8f61da9fa5d4d61e': created (progress 0%)
# 0:00:33 Job 'j-2508142053284a7c8f61da9fa5d4d61e': created (progress 0%)
# 0:00:44 Job 'j-2508142053284a7c8f61da9fa5d4d61e': running (progress N/A)
# 0:00:57 Job 'j-2508142053284a7c8f61da9fa5d4d61e': running (progress N/A)
# 0:01:12 Job 'j-2508142053284a7c8f61da9fa5d4d61e': running (progress N/A)
# 0:01:32 Job 'j-2508142053284a7c8f61da9fa5d4d61e': running (progress N/A)
# 0:01:56 Job 'j-2508142053284a7c8f61da9fa5d4d61e': error (progress N/A)
# Your batch job 'j-2508142053284a7c8f61da9fa5d4d61e' failed. Error logs:
# [{'id': '[1755204854522, 543432]', 'time': '2025-08-14T20:54:14.522Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142053284a7c8f61da9fa5d4d61e" and returned 0 results.'}, {'id': '[1755204855348, 208510]', 'time': '2025-08-14T20:54:15.348Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142053284a7c8f61da9fa5d4d61e" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-2508142053284a7c8f61da9fa5d4d61e').logs()`.
# [SKIP] Amatitlán 2025-02-25 -> Batch job 'j-2508142053284a7c8f61da9fa5d4d61e' didn't finish successfully. Status: error (after 0:01:56).
# 0:00:00 Job 'j-250814205526499284f9c566d9d80d1c': send 'start'
# 0:00:13 Job 'j-250814205526499284f9c566d9d80d1c': created (progress 0%)
# 0:00:19 Job 'j-250814205526499284f9c566d9d80d1c': created (progress 0%)
# 0:00:26 Job 'j-250814205526499284f9c566d9d80d1c': created (progress 0%)
# 0:00:34 Job 'j-250814205526499284f9c566d9d80d1c': created (progress 0%)
# 0:00:44 Job 'j-250814205526499284f9c566d9d80d1c': running (progress N/A)
# 0:00:57 Job 'j-250814205526499284f9c566d9d80d1c': running (progress N/A)
# 0:01:12 Job 'j-250814205526499284f9c566d9d80d1c': running (progress N/A)
# 0:01:32 Job 'j-250814205526499284f9c566d9d80d1c': running (progress N/A)
# 0:01:56 Job 'j-250814205526499284f9c566d9d80d1c': finished (progress 100%)
# [OK] Atitlán 2025-02-27
# 0:00:00 Job 'j-2508142100014cf8b414f91ded21082a': send 'start'
# 0:00:13 Job 'j-2508142100014cf8b414f91ded21082a': queued (progress 0%)
# 0:00:18 Job 'j-2508142100014cf8b414f91ded21082a': queued (progress 0%)
# 0:00:27 Job 'j-2508142100014cf8b414f91ded21082a': queued (progress 0%)
# 0:00:35 Job 'j-2508142100014cf8b414f91ded21082a': queued (progress 0%)
# 0:00:45 Job 'j-2508142100014cf8b414f91ded21082a': queued (progress 0%)
# 0:01:00 Job 'j-2508142100014cf8b414f91ded21082a': queued (progress 0%)
# 0:01:15 Job 'j-2508142100014cf8b414f91ded21082a': running (progress N/A)
# 0:01:38 Job 'j-2508142100014cf8b414f91ded21082a': running (progress N/A)
# 0:02:02 Job 'j-2508142100014cf8b414f91ded21082a': running (progress N/A)
# 0:02:32 Job 'j-2508142100014cf8b414f91ded21082a': finished (progress 100%)
# [OK] Amatitlán 2025-02-27
# 0:00:00 Job 'j-25081421025845ab888559999aa1c062': send 'start'
# 0:00:16 Job 'j-25081421025845ab888559999aa1c062': queued (progress 0%)
# 0:00:24 Job 'j-25081421025845ab888559999aa1c062': queued (progress 0%)
# 0:00:31 Job 'j-25081421025845ab888559999aa1c062': queued (progress 0%)
# 0:00:39 Job 'j-25081421025845ab888559999aa1c062': queued (progress 0%)
# 0:00:49 Job 'j-25081421025845ab888559999aa1c062': queued (progress 0%)
# 0:01:01 Job 'j-25081421025845ab888559999aa1c062': queued (progress 0%)
# 0:01:17 Job 'j-25081421025845ab888559999aa1c062': running (progress N/A)
# 0:01:37 Job 'j-25081421025845ab888559999aa1c062': running (progress N/A)
# 0:02:01 Job 'j-25081421025845ab888559999aa1c062': running (progress N/A)
# 0:02:31 Job 'j-25081421025845ab888559999aa1c062': finished (progress 100%)
# [OK] Atitlán 2025-03-02
# 0:00:00 Job 'j-2508142106354364b4f7fc87e7d01b1d': send 'start'
# 0:00:13 Job 'j-2508142106354364b4f7fc87e7d01b1d': created (progress 0%)
# 0:00:18 Job 'j-2508142106354364b4f7fc87e7d01b1d': created (progress 0%)
# 0:00:25 Job 'j-2508142106354364b4f7fc87e7d01b1d': created (progress 0%)
# 0:00:33 Job 'j-2508142106354364b4f7fc87e7d01b1d': running (progress N/A)
# 0:00:43 Job 'j-2508142106354364b4f7fc87e7d01b1d': running (progress N/A)
# 0:00:56 Job 'j-2508142106354364b4f7fc87e7d01b1d': running (progress N/A)
# 0:01:11 Job 'j-2508142106354364b4f7fc87e7d01b1d': running (progress N/A)
# 0:01:31 Job 'j-2508142106354364b4f7fc87e7d01b1d': running (progress N/A)
# 0:01:55 Job 'j-2508142106354364b4f7fc87e7d01b1d': error (progress N/A)
# Your batch job 'j-2508142106354364b4f7fc87e7d01b1d' failed. Error logs:
# [{'id': '[1755205637039, 634325]', 'time': '2025-08-14T21:07:17.039Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142106354364b4f7fc87e7d01b1d" and returned 0 results.'}, {'id': '[1755205638603, 495363]', 'time': '2025-08-14T21:07:18.603Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142106354364b4f7fc87e7d01b1d" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-2508142106354364b4f7fc87e7d01b1d').logs()`.
# [SKIP] Amatitlán 2025-03-02 -> Batch job 'j-2508142106354364b4f7fc87e7d01b1d' didn't finish successfully. Status: error (after 0:01:55).
# 0:00:00 Job 'j-250814210832400eaf4917da430b9fdd': send 'start'
# 0:00:13 Job 'j-250814210832400eaf4917da430b9fdd': created (progress 0%)
# 0:00:18 Job 'j-250814210832400eaf4917da430b9fdd': created (progress 0%)
# 0:00:24 Job 'j-250814210832400eaf4917da430b9fdd': created (progress 0%)
# 0:00:33 Job 'j-250814210832400eaf4917da430b9fdd': created (progress 0%)
# 0:00:43 Job 'j-250814210832400eaf4917da430b9fdd': running (progress N/A)
# 0:00:56 Job 'j-250814210832400eaf4917da430b9fdd': running (progress N/A)
# 0:01:11 Job 'j-250814210832400eaf4917da430b9fdd': running (progress N/A)
# 0:01:30 Job 'j-250814210832400eaf4917da430b9fdd': running (progress N/A)
# 0:01:55 Job 'j-250814210832400eaf4917da430b9fdd': running (progress N/A)
# 0:02:29 Job 'j-250814210832400eaf4917da430b9fdd': running (progress N/A)
# 0:03:06 Job 'j-250814210832400eaf4917da430b9fdd': finished (progress 100%)
# [OK] Atitlán 2025-03-04
# 0:00:00 Job 'j-250814211406435db685344133c99987': send 'start'
# 0:00:13 Job 'j-250814211406435db685344133c99987': created (progress 0%)
# 0:00:19 Job 'j-250814211406435db685344133c99987': created (progress 0%)
# 0:00:25 Job 'j-250814211406435db685344133c99987': created (progress 0%)
# 0:00:33 Job 'j-250814211406435db685344133c99987': created (progress 0%)
# 0:00:43 Job 'j-250814211406435db685344133c99987': created (progress 0%)
# 0:00:56 Job 'j-250814211406435db685344133c99987': created (progress 0%)
# 0:01:12 Job 'j-250814211406435db685344133c99987': running (progress N/A)
# 0:01:31 Job 'j-250814211406435db685344133c99987': running (progress N/A)
# 0:01:55 Job 'j-250814211406435db685344133c99987': running (progress N/A)
# 0:02:25 Job 'j-250814211406435db685344133c99987': finished (progress 100%)
# [OK] Amatitlán 2025-03-04
# 0:00:00 Job 'j-25081421170449038dfd9f5ea6eac082': send 'start'
# 0:00:13 Job 'j-25081421170449038dfd9f5ea6eac082': created (progress 0%)
# 0:00:18 Job 'j-25081421170449038dfd9f5ea6eac082': created (progress 0%)
# 0:00:25 Job 'j-25081421170449038dfd9f5ea6eac082': created (progress 0%)
# 0:00:33 Job 'j-25081421170449038dfd9f5ea6eac082': created (progress 0%)
# 0:00:43 Job 'j-25081421170449038dfd9f5ea6eac082': created (progress 0%)
# 0:00:56 Job 'j-25081421170449038dfd9f5ea6eac082': created (progress 0%)
# 0:01:11 Job 'j-25081421170449038dfd9f5ea6eac082': running (progress N/A)
# 0:01:31 Job 'j-25081421170449038dfd9f5ea6eac082': running (progress N/A)
# 0:01:55 Job 'j-25081421170449038dfd9f5ea6eac082': running (progress N/A)
# 0:02:25 Job 'j-25081421170449038dfd9f5ea6eac082': finished (progress 100%)
# [OK] Atitlán 2025-03-07
# 0:00:00 Job 'j-2508142120224758bebcd550b566c829': send 'start'
# 0:00:14 Job 'j-2508142120224758bebcd550b566c829': created (progress 0%)
# 0:00:19 Job 'j-2508142120224758bebcd550b566c829': created (progress 0%)
# 0:00:26 Job 'j-2508142120224758bebcd550b566c829': created (progress 0%)
# 0:00:34 Job 'j-2508142120224758bebcd550b566c829': created (progress 0%)
# 0:00:44 Job 'j-2508142120224758bebcd550b566c829': created (progress 0%)
# 0:00:57 Job 'j-2508142120224758bebcd550b566c829': running (progress N/A)
# 0:01:12 Job 'j-2508142120224758bebcd550b566c829': running (progress N/A)
# 0:01:32 Job 'j-2508142120224758bebcd550b566c829': running (progress N/A)
# 0:01:56 Job 'j-2508142120224758bebcd550b566c829': error (progress N/A)
# Your batch job 'j-2508142120224758bebcd550b566c829' failed. Error logs:
# [{'id': '[1755206478631, 281933]', 'time': '2025-08-14T21:21:18.631Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142120224758bebcd550b566c829" and returned 0 results.'}, {'id': '[1755206479975, 372194]', 'time': '2025-08-14T21:21:19.975Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142120224758bebcd550b566c829" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-2508142120224758bebcd550b566c829').logs()`.
# [SKIP] Amatitlán 2025-03-07 -> Batch job 'j-2508142120224758bebcd550b566c829' didn't finish successfully. Status: error (after 0:01:56).
# 0:00:00 Job 'j-25081421221943349d5d91b685d3663a': send 'start'
# 0:00:13 Job 'j-25081421221943349d5d91b685d3663a': created (progress 0%)
# 0:00:18 Job 'j-25081421221943349d5d91b685d3663a': created (progress 0%)
# 0:00:24 Job 'j-25081421221943349d5d91b685d3663a': created (progress 0%)
# 0:00:33 Job 'j-25081421221943349d5d91b685d3663a': created (progress 0%)
# 0:00:43 Job 'j-25081421221943349d5d91b685d3663a': created (progress 0%)
# 0:00:55 Job 'j-25081421221943349d5d91b685d3663a': running (progress N/A)
# 0:01:11 Job 'j-25081421221943349d5d91b685d3663a': running (progress N/A)
# 0:01:30 Job 'j-25081421221943349d5d91b685d3663a': running (progress N/A)
# 0:01:55 Job 'j-25081421221943349d5d91b685d3663a': finished (progress 100%)
# [OK] Atitlán 2025-03-09
# 0:00:00 Job 'j-25081421264542f3b7e7b5631fd324d7': send 'start'
# 0:00:14 Job 'j-25081421264542f3b7e7b5631fd324d7': created (progress 0%)
# 0:00:19 Job 'j-25081421264542f3b7e7b5631fd324d7': created (progress 0%)
# 0:00:25 Job 'j-25081421264542f3b7e7b5631fd324d7': running (progress N/A)
# 0:00:34 Job 'j-25081421264542f3b7e7b5631fd324d7': running (progress N/A)
# 0:00:44 Job 'j-25081421264542f3b7e7b5631fd324d7': running (progress N/A)
# 0:00:56 Job 'j-25081421264542f3b7e7b5631fd324d7': running (progress N/A)
# 0:01:12 Job 'j-25081421264542f3b7e7b5631fd324d7': running (progress N/A)
# 0:01:31 Job 'j-25081421264542f3b7e7b5631fd324d7': finished (progress 100%)
# [OK] Amatitlán 2025-03-09
# 0:00:00 Job 'j-2508142128384f29b66a88e2f7df8e46': send 'start'
# 0:00:13 Job 'j-2508142128384f29b66a88e2f7df8e46': created (progress 0%)
# 0:00:19 Job 'j-2508142128384f29b66a88e2f7df8e46': created (progress 0%)
# 0:00:25 Job 'j-2508142128384f29b66a88e2f7df8e46': created (progress 0%)
# 0:00:33 Job 'j-2508142128384f29b66a88e2f7df8e46': running (progress N/A)
# 0:00:44 Job 'j-2508142128384f29b66a88e2f7df8e46': running (progress N/A)
# 0:00:56 Job 'j-2508142128384f29b66a88e2f7df8e46': running (progress N/A)
# 0:01:12 Job 'j-2508142128384f29b66a88e2f7df8e46': running (progress N/A)
# 0:01:31 Job 'j-2508142128384f29b66a88e2f7df8e46': running (progress N/A)
# 0:01:55 Job 'j-2508142128384f29b66a88e2f7df8e46': running (progress N/A)
# 0:02:25 Job 'j-2508142128384f29b66a88e2f7df8e46': running (progress N/A)
# 0:03:03 Job 'j-2508142128384f29b66a88e2f7df8e46': finished (progress 100%)
# [OK] Atitlán 2025-03-12
# 0:00:00 Job 'j-2508142132444ad8b48293f36049687a': send 'start'
# 0:00:13 Job 'j-2508142132444ad8b48293f36049687a': created (progress 0%)
# 0:00:18 Job 'j-2508142132444ad8b48293f36049687a': created (progress 0%)
# 0:00:25 Job 'j-2508142132444ad8b48293f36049687a': running (progress N/A)
# 0:00:34 Job 'j-2508142132444ad8b48293f36049687a': running (progress N/A)
# 0:00:44 Job 'j-2508142132444ad8b48293f36049687a': running (progress N/A)
# 0:00:56 Job 'j-2508142132444ad8b48293f36049687a': running (progress N/A)
# 0:01:12 Job 'j-2508142132444ad8b48293f36049687a': running (progress N/A)
# 0:01:31 Job 'j-2508142132444ad8b48293f36049687a': error (progress N/A)
# Your batch job 'j-2508142132444ad8b48293f36049687a' failed. Error logs:
# [{'id': '[1755207206983, 650032]', 'time': '2025-08-14T21:33:26.983Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142132444ad8b48293f36049687a" and returned 0 results.'}, {'id': '[1755207208012, 956270]', 'time': '2025-08-14T21:33:28.012Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142132444ad8b48293f36049687a" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-2508142132444ad8b48293f36049687a').logs()`.
# [SKIP] Amatitlán 2025-03-12 -> Batch job 'j-2508142132444ad8b48293f36049687a' didn't finish successfully. Status: error (after 0:01:32).
# 0:00:00 Job 'j-250814213417412b9e3e42315dede0fe': send 'start'
# 0:00:13 Job 'j-250814213417412b9e3e42315dede0fe': created (progress 0%)
# 0:00:18 Job 'j-250814213417412b9e3e42315dede0fe': created (progress 0%)
# 0:00:25 Job 'j-250814213417412b9e3e42315dede0fe': created (progress 0%)
# 0:00:33 Job 'j-250814213417412b9e3e42315dede0fe': created (progress 0%)
# 0:00:43 Job 'j-250814213417412b9e3e42315dede0fe': created (progress 0%)
# 0:00:55 Job 'j-250814213417412b9e3e42315dede0fe': running (progress N/A)
# 0:01:11 Job 'j-250814213417412b9e3e42315dede0fe': running (progress N/A)
# 0:01:30 Job 'j-250814213417412b9e3e42315dede0fe': running (progress N/A)
# 0:01:55 Job 'j-250814213417412b9e3e42315dede0fe': finished (progress 100%)
# [OK] Atitlán 2025-03-14
# 0:00:00 Job 'j-2508142138354410b0babddd51fa8f46': send 'start'
# 0:00:13 Job 'j-2508142138354410b0babddd51fa8f46': created (progress 0%)
# 0:00:18 Job 'j-2508142138354410b0babddd51fa8f46': created (progress 0%)
# 0:00:24 Job 'j-2508142138354410b0babddd51fa8f46': created (progress 0%)
# 0:00:33 Job 'j-2508142138354410b0babddd51fa8f46': running (progress N/A)
# 0:00:43 Job 'j-2508142138354410b0babddd51fa8f46': running (progress N/A)
# 0:00:55 Job 'j-2508142138354410b0babddd51fa8f46': running (progress N/A)
# 0:01:11 Job 'j-2508142138354410b0babddd51fa8f46': running (progress N/A)
# 0:01:31 Job 'j-2508142138354410b0babddd51fa8f46': running (progress N/A)
# 0:01:55 Job 'j-2508142138354410b0babddd51fa8f46': finished (progress 100%)
# [OK] Amatitlán 2025-03-14
# 0:00:00 Job 'j-25081421405149579698dd03b8aff0af': send 'start'
# 0:00:14 Job 'j-25081421405149579698dd03b8aff0af': created (progress 0%)
# 0:00:19 Job 'j-25081421405149579698dd03b8aff0af': running (progress N/A)
# 0:00:26 Job 'j-25081421405149579698dd03b8aff0af': running (progress N/A)
# 0:00:34 Job 'j-25081421405149579698dd03b8aff0af': running (progress N/A)
# 0:00:44 Job 'j-25081421405149579698dd03b8aff0af': running (progress N/A)
# 0:00:57 Job 'j-25081421405149579698dd03b8aff0af': running (progress N/A)
# 0:01:12 Job 'j-25081421405149579698dd03b8aff0af': running (progress N/A)
# 0:01:32 Job 'j-25081421405149579698dd03b8aff0af': running (progress N/A)
# 0:01:56 Job 'j-25081421405149579698dd03b8aff0af': running (progress N/A)
# 0:02:26 Job 'j-25081421405149579698dd03b8aff0af': finished (progress 100%)
# [OK] Atitlán 2025-03-19
# 0:00:00 Job 'j-25081421451045ab8df45142d1eb47f1': send 'start'
# 0:00:13 Job 'j-25081421451045ab8df45142d1eb47f1': created (progress 0%)
# 0:00:18 Job 'j-25081421451045ab8df45142d1eb47f1': created (progress 0%)
# 0:00:25 Job 'j-25081421451045ab8df45142d1eb47f1': created (progress 0%)
# 0:00:33 Job 'j-25081421451045ab8df45142d1eb47f1': created (progress 0%)
# 0:00:43 Job 'j-25081421451045ab8df45142d1eb47f1': created (progress 0%)
# 0:00:56 Job 'j-25081421451045ab8df45142d1eb47f1': created (progress 0%)
# 0:01:12 Job 'j-25081421451045ab8df45142d1eb47f1': running (progress N/A)
# 0:01:31 Job 'j-25081421451045ab8df45142d1eb47f1': running (progress N/A)
# 0:01:55 Job 'j-25081421451045ab8df45142d1eb47f1': running (progress N/A)
# 0:02:26 Job 'j-25081421451045ab8df45142d1eb47f1': finished (progress 100%)
# [OK] Amatitlán 2025-03-19
# 0:00:00 Job 'j-2508142147564c77b310a0fc641228d8': send 'start'
# 0:00:13 Job 'j-2508142147564c77b310a0fc641228d8': queued (progress 0%)
# 0:00:18 Job 'j-2508142147564c77b310a0fc641228d8': queued (progress 0%)
# 0:00:25 Job 'j-2508142147564c77b310a0fc641228d8': queued (progress 0%)
# 0:00:33 Job 'j-2508142147564c77b310a0fc641228d8': queued (progress 0%)
# 0:00:43 Job 'j-2508142147564c77b310a0fc641228d8': queued (progress 0%)
# 0:00:55 Job 'j-2508142147564c77b310a0fc641228d8': queued (progress 0%)
# 0:01:11 Job 'j-2508142147564c77b310a0fc641228d8': running (progress N/A)
# 0:01:31 Job 'j-2508142147564c77b310a0fc641228d8': running (progress N/A)
# 0:01:55 Job 'j-2508142147564c77b310a0fc641228d8': running (progress N/A)
# 0:02:25 Job 'j-2508142147564c77b310a0fc641228d8': finished (progress 100%)
# [OK] Atitlán 2025-03-22
# 0:00:00 Job 'j-2508142151094d92972a061fc8f534f1': send 'start'
# 0:00:13 Job 'j-2508142151094d92972a061fc8f534f1': created (progress 0%)
# 0:00:18 Job 'j-2508142151094d92972a061fc8f534f1': created (progress 0%)
# 0:00:25 Job 'j-2508142151094d92972a061fc8f534f1': created (progress 0%)
# 0:00:33 Job 'j-2508142151094d92972a061fc8f534f1': created (progress 0%)
# 0:00:43 Job 'j-2508142151094d92972a061fc8f534f1': created (progress 0%)
# 0:00:55 Job 'j-2508142151094d92972a061fc8f534f1': created (progress 0%)
# 0:01:11 Job 'j-2508142151094d92972a061fc8f534f1': error (progress N/A)
# Your batch job 'j-2508142151094d92972a061fc8f534f1' failed. Error logs:
# [{'id': '[1755208309597, 2088]', 'time': '2025-08-14T21:51:49.597Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142151094d92972a061fc8f534f1" and returned 0 results.'}, {'id': '[1755208310448, 768230]', 'time': '2025-08-14T21:51:50.448Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142151094d92972a061fc8f534f1" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-2508142151094d92972a061fc8f534f1').logs()`.
# [SKIP] Amatitlán 2025-03-22 -> Batch job 'j-2508142151094d92972a061fc8f534f1' didn't finish successfully. Status: error (after 0:01:12).
# 0:00:00 Job 'j-2508142152224150bfa53de92852ac8e': send 'start'
# 0:00:13 Job 'j-2508142152224150bfa53de92852ac8e': created (progress 0%)
# 0:00:18 Job 'j-2508142152224150bfa53de92852ac8e': created (progress 0%)
# 0:00:25 Job 'j-2508142152224150bfa53de92852ac8e': created (progress 0%)
# 0:00:33 Job 'j-2508142152224150bfa53de92852ac8e': created (progress 0%)
# 0:00:43 Job 'j-2508142152224150bfa53de92852ac8e': created (progress 0%)
# 0:00:55 Job 'j-2508142152224150bfa53de92852ac8e': running (progress N/A)
# 0:01:11 Job 'j-2508142152224150bfa53de92852ac8e': running (progress N/A)
# 0:01:31 Job 'j-2508142152224150bfa53de92852ac8e': running (progress N/A)
# 0:01:55 Job 'j-2508142152224150bfa53de92852ac8e': running (progress N/A)
# 0:02:25 Job 'j-2508142152224150bfa53de92852ac8e': running (progress N/A)
# 0:03:03 Job 'j-2508142152224150bfa53de92852ac8e': finished (progress 100%)
# [OK] Atitlán 2025-03-24
# 0:00:00 Job 'j-25081421575147a18c64b81b0766a61f': send 'start'
# 0:00:13 Job 'j-25081421575147a18c64b81b0766a61f': created (progress 0%)
# 0:00:18 Job 'j-25081421575147a18c64b81b0766a61f': running (progress N/A)
# 0:00:25 Job 'j-25081421575147a18c64b81b0766a61f': running (progress N/A)
# 0:00:33 Job 'j-25081421575147a18c64b81b0766a61f': running (progress N/A)
# 0:00:43 Job 'j-25081421575147a18c64b81b0766a61f': running (progress N/A)
# 0:00:56 Job 'j-25081421575147a18c64b81b0766a61f': running (progress N/A)
# 0:01:12 Job 'j-25081421575147a18c64b81b0766a61f': running (progress N/A)
# 0:01:31 Job 'j-25081421575147a18c64b81b0766a61f': running (progress N/A)
# 0:01:55 Job 'j-25081421575147a18c64b81b0766a61f': running (progress N/A)
# 0:02:26 Job 'j-25081421575147a18c64b81b0766a61f': finished (progress 100%)
# [OK] Amatitlán 2025-03-24
# 0:00:00 Job 'j-250814220042409a83020f1ae40b8881': send 'start'
# 0:00:13 Job 'j-250814220042409a83020f1ae40b8881': created (progress 0%)
# 0:00:18 Job 'j-250814220042409a83020f1ae40b8881': created (progress 0%)
# 0:00:25 Job 'j-250814220042409a83020f1ae40b8881': created (progress 0%)
# 0:00:33 Job 'j-250814220042409a83020f1ae40b8881': running (progress N/A)
# 0:00:43 Job 'j-250814220042409a83020f1ae40b8881': running (progress N/A)
# 0:00:56 Job 'j-250814220042409a83020f1ae40b8881': running (progress N/A)
# 0:01:11 Job 'j-250814220042409a83020f1ae40b8881': running (progress N/A)
# 0:01:31 Job 'j-250814220042409a83020f1ae40b8881': running (progress N/A)
# 0:01:55 Job 'j-250814220042409a83020f1ae40b8881': running (progress N/A)
# 0:02:25 Job 'j-250814220042409a83020f1ae40b8881': running (progress N/A)
# 0:03:03 Job 'j-250814220042409a83020f1ae40b8881': finished (progress 100%)
# [OK] Atitlán 2025-03-26
# 0:00:00 Job 'j-25081422061941f3bf83ecf2e7fa204e': send 'start'
# 0:00:13 Job 'j-25081422061941f3bf83ecf2e7fa204e': created (progress 0%)
# 0:00:18 Job 'j-25081422061941f3bf83ecf2e7fa204e': created (progress 0%)
# 0:00:24 Job 'j-25081422061941f3bf83ecf2e7fa204e': created (progress 0%)
# 0:00:33 Job 'j-25081422061941f3bf83ecf2e7fa204e': created (progress 0%)
# 0:00:43 Job 'j-25081422061941f3bf83ecf2e7fa204e': created (progress 0%)
# 0:00:55 Job 'j-25081422061941f3bf83ecf2e7fa204e': running (progress N/A)
# 0:01:11 Job 'j-25081422061941f3bf83ecf2e7fa204e': running (progress N/A)
# 0:01:30 Job 'j-25081422061941f3bf83ecf2e7fa204e': running (progress N/A)
# 0:01:54 Job 'j-25081422061941f3bf83ecf2e7fa204e': finished (progress 100%)
# [OK] Amatitlán 2025-03-26
# 0:00:00 Job 'j-2508142208384828ad4677e52b32fb41': send 'start'
# 0:00:13 Job 'j-2508142208384828ad4677e52b32fb41': created (progress 0%)
# 0:00:18 Job 'j-2508142208384828ad4677e52b32fb41': created (progress 0%)
# 0:00:24 Job 'j-2508142208384828ad4677e52b32fb41': created (progress 0%)
# 0:00:33 Job 'j-2508142208384828ad4677e52b32fb41': running (progress N/A)
# 0:00:43 Job 'j-2508142208384828ad4677e52b32fb41': running (progress N/A)
# 0:00:56 Job 'j-2508142208384828ad4677e52b32fb41': running (progress N/A)
# 0:01:11 Job 'j-2508142208384828ad4677e52b32fb41': running (progress N/A)
# 0:01:31 Job 'j-2508142208384828ad4677e52b32fb41': running (progress N/A)
# 0:01:55 Job 'j-2508142208384828ad4677e52b32fb41': running (progress N/A)
# 0:02:25 Job 'j-2508142208384828ad4677e52b32fb41': running (progress N/A)
# 0:03:03 Job 'j-2508142208384828ad4677e52b32fb41': finished (progress 100%)
# [OK] Atitlán 2025-04-03
# 0:00:00 Job 'j-2508142214094570aa56e453d833d0de': send 'start'
# 0:00:13 Job 'j-2508142214094570aa56e453d833d0de': created (progress 0%)
# 0:00:18 Job 'j-2508142214094570aa56e453d833d0de': created (progress 0%)
# 0:00:25 Job 'j-2508142214094570aa56e453d833d0de': created (progress 0%)
# 0:00:33 Job 'j-2508142214094570aa56e453d833d0de': created (progress 0%)
# 0:00:43 Job 'j-2508142214094570aa56e453d833d0de': created (progress 0%)
# 0:00:55 Job 'j-2508142214094570aa56e453d833d0de': created (progress 0%)
# 0:01:11 Job 'j-2508142214094570aa56e453d833d0de': running (progress N/A)
# 0:01:30 Job 'j-2508142214094570aa56e453d833d0de': running (progress N/A)
# 0:01:55 Job 'j-2508142214094570aa56e453d833d0de': running (progress N/A)
# 0:02:25 Job 'j-2508142214094570aa56e453d833d0de': finished (progress 100%)
# [OK] Amatitlán 2025-04-03
# 0:00:00 Job 'j-2508142217014793bf2a7d5b74af3f84': send 'start'
# 0:00:13 Job 'j-2508142217014793bf2a7d5b74af3f84': queued (progress 0%)
# 0:00:18 Job 'j-2508142217014793bf2a7d5b74af3f84': queued (progress 0%)
# 0:00:24 Job 'j-2508142217014793bf2a7d5b74af3f84': queued (progress 0%)
# 0:00:33 Job 'j-2508142217014793bf2a7d5b74af3f84': queued (progress 0%)
# 0:00:43 Job 'j-2508142217014793bf2a7d5b74af3f84': queued (progress 0%)
# 0:00:55 Job 'j-2508142217014793bf2a7d5b74af3f84': queued (progress 0%)
# 0:01:11 Job 'j-2508142217014793bf2a7d5b74af3f84': running (progress N/A)
# 0:01:30 Job 'j-2508142217014793bf2a7d5b74af3f84': running (progress N/A)
# 0:01:54 Job 'j-2508142217014793bf2a7d5b74af3f84': running (progress N/A)
# 0:02:25 Job 'j-2508142217014793bf2a7d5b74af3f84': finished (progress 100%)
# [OK] Atitlán 2025-04-11
# 0:00:00 Job 'j-2508142220404982b76568e337c89280': send 'start'
# 0:00:16 Job 'j-2508142220404982b76568e337c89280': created (progress 0%)
# 0:00:21 Job 'j-2508142220404982b76568e337c89280': created (progress 0%)
# 0:00:28 Job 'j-2508142220404982b76568e337c89280': created (progress 0%)
# 0:00:36 Job 'j-2508142220404982b76568e337c89280': running (progress N/A)
# 0:00:46 Job 'j-2508142220404982b76568e337c89280': running (progress N/A)
# 0:00:58 Job 'j-2508142220404982b76568e337c89280': running (progress N/A)
# 0:01:14 Job 'j-2508142220404982b76568e337c89280': running (progress N/A)
# 0:01:33 Job 'j-2508142220404982b76568e337c89280': error (progress N/A)
# Your batch job 'j-2508142220404982b76568e337c89280' failed. Error logs:
# [{'id': '[1755210078256, 98603]', 'time': '2025-08-14T22:21:18.256Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142220404982b76568e337c89280" and returned 0 results.'}, {'id': '[1755210080246, 611824]', 'time': '2025-08-14T22:21:20.246Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142220404982b76568e337c89280" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-2508142220404982b76568e337c89280').logs()`.
# [SKIP] Amatitlán 2025-04-11 -> Batch job 'j-2508142220404982b76568e337c89280' didn't finish successfully. Status: error (after 0:01:34).
# 0:00:00 Job 'j-2508142222164f0c90e0dd16a1127609': send 'start'
# 0:00:13 Job 'j-2508142222164f0c90e0dd16a1127609': created (progress 0%)
# 0:00:19 Job 'j-2508142222164f0c90e0dd16a1127609': created (progress 0%)
# 0:00:25 Job 'j-2508142222164f0c90e0dd16a1127609': created (progress 0%)
# 0:00:34 Job 'j-2508142222164f0c90e0dd16a1127609': created (progress 0%)
# 0:00:44 Job 'j-2508142222164f0c90e0dd16a1127609': created (progress 0%)
# 0:00:57 Job 'j-2508142222164f0c90e0dd16a1127609': running (progress N/A)
# 0:01:12 Job 'j-2508142222164f0c90e0dd16a1127609': running (progress N/A)
# 0:01:32 Job 'j-2508142222164f0c90e0dd16a1127609': running (progress N/A)
# 0:01:56 Job 'j-2508142222164f0c90e0dd16a1127609': running (progress N/A)
# 0:02:27 Job 'j-2508142222164f0c90e0dd16a1127609': finished (progress 100%)
# [OK] Atitlán 2025-04-13
# 0:00:00 Job 'j-250814222633449aaf3703a51b8df7b3': send 'start'
# 0:00:14 Job 'j-250814222633449aaf3703a51b8df7b3': created (progress 0%)
# 0:00:19 Job 'j-250814222633449aaf3703a51b8df7b3': created (progress 0%)
# 0:00:26 Job 'j-250814222633449aaf3703a51b8df7b3': created (progress 0%)
# 0:00:34 Job 'j-250814222633449aaf3703a51b8df7b3': created (progress 0%)
# 0:00:44 Job 'j-250814222633449aaf3703a51b8df7b3': running (progress N/A)
# 0:00:56 Job 'j-250814222633449aaf3703a51b8df7b3': running (progress N/A)
# 0:01:12 Job 'j-250814222633449aaf3703a51b8df7b3': running (progress N/A)
# 0:01:31 Job 'j-250814222633449aaf3703a51b8df7b3': running (progress N/A)
# 0:01:55 Job 'j-250814222633449aaf3703a51b8df7b3': finished (progress 100%)
# [OK] Amatitlán 2025-04-13
# 0:00:00 Job 'j-250814222849416f9bcb14445915c65b': send 'start'
# 0:00:16 Job 'j-250814222849416f9bcb14445915c65b': created (progress 0%)
# 0:00:22 Job 'j-250814222849416f9bcb14445915c65b': running (progress N/A)
# 0:00:28 Job 'j-250814222849416f9bcb14445915c65b': running (progress N/A)
# 0:00:36 Job 'j-250814222849416f9bcb14445915c65b': running (progress N/A)
# 0:00:47 Job 'j-250814222849416f9bcb14445915c65b': running (progress N/A)
# 0:00:59 Job 'j-250814222849416f9bcb14445915c65b': running (progress N/A)
# 0:01:15 Job 'j-250814222849416f9bcb14445915c65b': running (progress N/A)
# 0:01:34 Job 'j-250814222849416f9bcb14445915c65b': running (progress N/A)
# 0:01:59 Job 'j-250814222849416f9bcb14445915c65b': running (progress N/A)
# 0:02:29 Job 'j-250814222849416f9bcb14445915c65b': finished (progress 100%)
# [OK] Atitlán 2025-04-15
# 0:00:00 Job 'j-2508142233334876972d1b0582388cda': send 'start'
# 0:00:13 Job 'j-2508142233334876972d1b0582388cda': created (progress 0%)
# 0:00:18 Job 'j-2508142233334876972d1b0582388cda': created (progress 0%)
# 0:00:25 Job 'j-2508142233334876972d1b0582388cda': created (progress 0%)
# 0:00:33 Job 'j-2508142233334876972d1b0582388cda': created (progress 0%)
# 0:00:43 Job 'j-2508142233334876972d1b0582388cda': running (progress N/A)
# 0:00:56 Job 'j-2508142233334876972d1b0582388cda': running (progress N/A)
# 0:01:11 Job 'j-2508142233334876972d1b0582388cda': running (progress N/A)
# 0:01:31 Job 'j-2508142233334876972d1b0582388cda': running (progress N/A)
# 0:01:55 Job 'j-2508142233334876972d1b0582388cda': finished (progress 100%)
# [OK] Amatitlán 2025-04-15
# 0:00:00 Job 'j-2508142235484d2cb1da08ae3eb0bbdb': send 'start'
# 0:00:13 Job 'j-2508142235484d2cb1da08ae3eb0bbdb': created (progress 0%)
# 0:00:18 Job 'j-2508142235484d2cb1da08ae3eb0bbdb': created (progress 0%)
# 0:00:24 Job 'j-2508142235484d2cb1da08ae3eb0bbdb': running (progress N/A)
# 0:00:33 Job 'j-2508142235484d2cb1da08ae3eb0bbdb': running (progress N/A)
# 0:00:43 Job 'j-2508142235484d2cb1da08ae3eb0bbdb': running (progress N/A)
# 0:00:55 Job 'j-2508142235484d2cb1da08ae3eb0bbdb': running (progress N/A)
# 0:01:11 Job 'j-2508142235484d2cb1da08ae3eb0bbdb': running (progress N/A)
# 0:01:30 Job 'j-2508142235484d2cb1da08ae3eb0bbdb': running (progress N/A)
# 0:01:54 Job 'j-2508142235484d2cb1da08ae3eb0bbdb': running (progress N/A)
# 0:02:25 Job 'j-2508142235484d2cb1da08ae3eb0bbdb': finished (progress 100%)
# [OK] Atitlán 2025-04-16
# 0:00:00 Job 'j-2508142239024c4988b1081fe75ceec6': send 'start'
# 0:00:13 Job 'j-2508142239024c4988b1081fe75ceec6': queued (progress 0%)
# 0:00:18 Job 'j-2508142239024c4988b1081fe75ceec6': queued (progress 0%)
# 0:00:25 Job 'j-2508142239024c4988b1081fe75ceec6': queued (progress 0%)
# 0:00:33 Job 'j-2508142239024c4988b1081fe75ceec6': queued (progress 0%)
# 0:00:43 Job 'j-2508142239024c4988b1081fe75ceec6': queued (progress 0%)
# 0:00:56 Job 'j-2508142239024c4988b1081fe75ceec6': queued (progress 0%)
# 0:01:11 Job 'j-2508142239024c4988b1081fe75ceec6': error (progress N/A)
# Your batch job 'j-2508142239024c4988b1081fe75ceec6' failed. Error logs:
# [{'id': '[1755211193231, 175950]', 'time': '2025-08-14T22:39:53.231Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142239024c4988b1081fe75ceec6" and returned 0 results.'}, {'id': '[1755211194253, 577763]', 'time': '2025-08-14T22:39:54.253Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-2508142239024c4988b1081fe75ceec6" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-2508142239024c4988b1081fe75ceec6').logs()`.
# [SKIP] Amatitlán 2025-04-16 -> Batch job 'j-2508142239024c4988b1081fe75ceec6' didn't finish successfully. Status: error (after 0:01:12).
# 0:00:00 Job 'j-250814224015460da4bc2a81857b2d47': send 'start'
# 0:00:13 Job 'j-250814224015460da4bc2a81857b2d47': created (progress 0%)
# 0:00:18 Job 'j-250814224015460da4bc2a81857b2d47': created (progress 0%)
# 0:00:25 Job 'j-250814224015460da4bc2a81857b2d47': created (progress 0%)
# 0:00:33 Job 'j-250814224015460da4bc2a81857b2d47': created (progress 0%)
# 0:00:46 Job 'j-250814224015460da4bc2a81857b2d47': created (progress 0%)
# 0:00:58 Job 'j-250814224015460da4bc2a81857b2d47': running (progress N/A)
# 0:01:14 Job 'j-250814224015460da4bc2a81857b2d47': running (progress N/A)
# 0:01:33 Job 'j-250814224015460da4bc2a81857b2d47': running (progress N/A)
# 0:01:58 Job 'j-250814224015460da4bc2a81857b2d47': finished (progress 100%)
# [OK] Atitlán 2025-04-18
# 0:00:00 Job 'j-2508142244414b6fa5825214632fa1db': send 'start'
# 0:00:13 Job 'j-2508142244414b6fa5825214632fa1db': created (progress 0%)
# 0:00:18 Job 'j-2508142244414b6fa5825214632fa1db': created (progress 0%)
# 0:00:25 Job 'j-2508142244414b6fa5825214632fa1db': created (progress 0%)
# 0:00:33 Job 'j-2508142244414b6fa5825214632fa1db': running (progress N/A)
# 0:00:43 Job 'j-2508142244414b6fa5825214632fa1db': running (progress N/A)
# 0:00:56 Job 'j-2508142244414b6fa5825214632fa1db': running (progress N/A)
# 0:01:12 Job 'j-2508142244414b6fa5825214632fa1db': running (progress N/A)
# 0:01:31 Job 'j-2508142244414b6fa5825214632fa1db': finished (progress 100%)
# [OK] Amatitlán 2025-04-18
# 0:00:00 Job 'j-2508142246384aa2aed645f7030e5eed': send 'start'
# 0:00:13 Job 'j-2508142246384aa2aed645f7030e5eed': created (progress 0%)
# 0:00:18 Job 'j-2508142246384aa2aed645f7030e5eed': created (progress 0%)
# 0:00:25 Job 'j-2508142246384aa2aed645f7030e5eed': created (progress 0%)
# 0:00:33 Job 'j-2508142246384aa2aed645f7030e5eed': running (progress N/A)
# 0:00:43 Job 'j-2508142246384aa2aed645f7030e5eed': running (progress N/A)
# 0:00:56 Job 'j-2508142246384aa2aed645f7030e5eed': running (progress N/A)
# 0:01:11 Job 'j-2508142246384aa2aed645f7030e5eed': running (progress N/A)
# 0:01:31 Job 'j-2508142246384aa2aed645f7030e5eed': running (progress N/A)
# 0:01:55 Job 'j-2508142246384aa2aed645f7030e5eed': running (progress N/A)
# 0:02:25 Job 'j-2508142246384aa2aed645f7030e5eed': running (progress N/A)
# 0:03:03 Job 'j-2508142246384aa2aed645f7030e5eed': finished (progress 100%)
# [OK] Atitlán 2025-04-28
# 0:00:00 Job 'j-25081422520941d5be876ce3a14a3d0f': send 'start'
# 0:00:13 Job 'j-25081422520941d5be876ce3a14a3d0f': created (progress 0%)
# 0:00:18 Job 'j-25081422520941d5be876ce3a14a3d0f': created (progress 0%)
# 0:00:24 Job 'j-25081422520941d5be876ce3a14a3d0f': created (progress 0%)
# 0:00:33 Job 'j-25081422520941d5be876ce3a14a3d0f': created (progress 0%)
# 0:00:43 Job 'j-25081422520941d5be876ce3a14a3d0f': created (progress 0%)
# 0:00:56 Job 'j-25081422520941d5be876ce3a14a3d0f': created (progress 0%)
# 0:01:11 Job 'j-25081422520941d5be876ce3a14a3d0f': running (progress N/A)
# 0:01:31 Job 'j-25081422520941d5be876ce3a14a3d0f': running (progress N/A)
# 0:01:55 Job 'j-25081422520941d5be876ce3a14a3d0f': running (progress N/A)
# 0:02:25 Job 'j-25081422520941d5be876ce3a14a3d0f': finished (progress 100%)
# [OK] Amatitlán 2025-04-28
# 0:00:00 Job 'j-2508142254544865b31ee7469a857dfa': send 'start'
# 0:00:13 Job 'j-2508142254544865b31ee7469a857dfa': created (progress 0%)
# 0:00:18 Job 'j-2508142254544865b31ee7469a857dfa': queued (progress 0%)
# 0:00:25 Job 'j-2508142254544865b31ee7469a857dfa': queued (progress 0%)
# 0:00:33 Job 'j-2508142254544865b31ee7469a857dfa': queued (progress 0%)
# 0:00:43 Job 'j-2508142254544865b31ee7469a857dfa': queued (progress 0%)
# 0:00:56 Job 'j-2508142254544865b31ee7469a857dfa': queued (progress 0%)
# 0:01:11 Job 'j-2508142254544865b31ee7469a857dfa': queued (progress 0%)
# 0:01:31 Job 'j-2508142254544865b31ee7469a857dfa': running (progress N/A)
# 0:01:55 Job 'j-2508142254544865b31ee7469a857dfa': running (progress N/A)
# 0:02:25 Job 'j-2508142254544865b31ee7469a857dfa': finished (progress 100%)
# [OK] Atitlán 2025-05-03
# 0:00:00 Job 'j-25081423001442229543390335287af4': send 'start'
# 0:00:14 Job 'j-25081423001442229543390335287af4': created (progress 0%)
# 0:00:20 Job 'j-25081423001442229543390335287af4': created (progress 0%)
# 0:00:26 Job 'j-25081423001442229543390335287af4': created (progress 0%)
# 0:00:35 Job 'j-25081423001442229543390335287af4': created (progress 0%)
# 0:00:47 Job 'j-25081423001442229543390335287af4': created (progress 0%)
# 0:01:00 Job 'j-25081423001442229543390335287af4': running (progress N/A)
# 0:01:16 Job 'j-25081423001442229543390335287af4': running (progress N/A)
# 0:01:35 Job 'j-25081423001442229543390335287af4': running (progress N/A)
# 0:01:59 Job 'j-25081423001442229543390335287af4': running (progress N/A)
# 0:02:29 Job 'j-25081423001442229543390335287af4': finished (progress 100%)
# [OK] Amatitlán 2025-05-03
# 0:00:00 Job 'j-2508142303074fb68c001e960ef278a3': send 'start'
# 0:00:13 Job 'j-2508142303074fb68c001e960ef278a3': created (progress 0%)
# 0:00:18 Job 'j-2508142303074fb68c001e960ef278a3': created (progress 0%)
# 0:00:25 Job 'j-2508142303074fb68c001e960ef278a3': created (progress 0%)
# 0:00:33 Job 'j-2508142303074fb68c001e960ef278a3': created (progress 0%)
# 0:00:43 Job 'j-2508142303074fb68c001e960ef278a3': created (progress 0%)
# 0:00:56 Job 'j-2508142303074fb68c001e960ef278a3': created (progress 0%)
# 0:01:12 Job 'j-2508142303074fb68c001e960ef278a3': running (progress N/A)
# 0:01:31 Job 'j-2508142303074fb68c001e960ef278a3': running (progress N/A)
# 0:01:55 Job 'j-2508142303074fb68c001e960ef278a3': running (progress N/A)
# 0:02:25 Job 'j-2508142303074fb68c001e960ef278a3': finished (progress 100%)
# [OK] Atitlán 2025-05-13
# 0:00:00 Job 'j-2508142308024beaaa966149d3a7ea76': send 'start'
# 0:00:13 Job 'j-2508142308024beaaa966149d3a7ea76': queued (progress 0%)
# 0:00:18 Job 'j-2508142308024beaaa966149d3a7ea76': queued (progress 0%)
# 0:00:25 Job 'j-2508142308024beaaa966149d3a7ea76': queued (progress 0%)
# 0:00:33 Job 'j-2508142308024beaaa966149d3a7ea76': queued (progress 0%)
# 0:00:43 Job 'j-2508142308024beaaa966149d3a7ea76': queued (progress 0%)
# 0:00:56 Job 'j-2508142308024beaaa966149d3a7ea76': queued (progress 0%)
# 0:01:11 Job 'j-2508142308024beaaa966149d3a7ea76': running (progress N/A)
# 0:01:31 Job 'j-2508142308024beaaa966149d3a7ea76': running (progress N/A)
# 0:01:55 Job 'j-2508142308024beaaa966149d3a7ea76': running (progress N/A)
# 0:02:25 Job 'j-2508142308024beaaa966149d3a7ea76': finished (progress 100%)
# [OK] Amatitlán 2025-05-13
# 0:00:00 Job 'j-25081423105449a59394d1811c55fc7d': send 'start'
# 0:00:13 Job 'j-25081423105449a59394d1811c55fc7d': created (progress 0%)
# 0:00:18 Job 'j-25081423105449a59394d1811c55fc7d': queued (progress 0%)
# 0:00:25 Job 'j-25081423105449a59394d1811c55fc7d': queued (progress 0%)
# 0:00:33 Job 'j-25081423105449a59394d1811c55fc7d': queued (progress 0%)
# 0:00:43 Job 'j-25081423105449a59394d1811c55fc7d': queued (progress 0%)
# 0:00:56 Job 'j-25081423105449a59394d1811c55fc7d': queued (progress 0%)
# 0:01:11 Job 'j-25081423105449a59394d1811c55fc7d': queued (progress 0%)
# 0:01:31 Job 'j-25081423105449a59394d1811c55fc7d': running (progress N/A)
# 0:01:55 Job 'j-25081423105449a59394d1811c55fc7d': running (progress N/A)
# 0:02:25 Job 'j-25081423105449a59394d1811c55fc7d': finished (progress 100%)
# [OK] Atitlán 2025-05-28
# 0:00:00 Job 'j-25081423160243b8aed8bd8dba0009d7': send 'start'
# 0:00:13 Job 'j-25081423160243b8aed8bd8dba0009d7': queued (progress 0%)
# 0:00:19 Job 'j-25081423160243b8aed8bd8dba0009d7': queued (progress 0%)
# 0:00:25 Job 'j-25081423160243b8aed8bd8dba0009d7': queued (progress 0%)
# 0:00:34 Job 'j-25081423160243b8aed8bd8dba0009d7': queued (progress 0%)
# 0:00:44 Job 'j-25081423160243b8aed8bd8dba0009d7': queued (progress 0%)
# 0:00:56 Job 'j-25081423160243b8aed8bd8dba0009d7': queued (progress 0%)
# 0:01:12 Job 'j-25081423160243b8aed8bd8dba0009d7': running (progress N/A)
# 0:01:31 Job 'j-25081423160243b8aed8bd8dba0009d7': running (progress N/A)
# 0:01:55 Job 'j-25081423160243b8aed8bd8dba0009d7': running (progress N/A)
# 0:02:26 Job 'j-25081423160243b8aed8bd8dba0009d7': finished (progress 100%)
# [OK] Amatitlán 2025-05-28
# 0:00:00 Job 'j-2508142318544449a0eb4bb3a35535c3': send 'start'
# 0:00:13 Job 'j-2508142318544449a0eb4bb3a35535c3': created (progress 0%)
# 0:00:18 Job 'j-2508142318544449a0eb4bb3a35535c3': queued (progress 0%)
# 0:00:25 Job 'j-2508142318544449a0eb4bb3a35535c3': queued (progress 0%)
# 0:00:33 Job 'j-2508142318544449a0eb4bb3a35535c3': queued (progress 0%)
# 0:00:43 Job 'j-2508142318544449a0eb4bb3a35535c3': queued (progress 0%)
# 0:00:55 Job 'j-2508142318544449a0eb4bb3a35535c3': queued (progress 0%)
# 0:01:11 Job 'j-2508142318544449a0eb4bb3a35535c3': queued (progress 0%)
# 0:01:30 Job 'j-2508142318544449a0eb4bb3a35535c3': running (progress N/A)
# 0:01:54 Job 'j-2508142318544449a0eb4bb3a35535c3': running (progress N/A)
# 0:02:25 Job 'j-2508142318544449a0eb4bb3a35535c3': finished (progress 100%)
# [OK] Atitlán 2025-07-10
# 0:00:00 Job 'j-25081423220749979514c392aefb5eb4': send 'start'
# 0:00:14 Job 'j-25081423220749979514c392aefb5eb4': created (progress 0%)
# 0:00:19 Job 'j-25081423220749979514c392aefb5eb4': created (progress 0%)
# 0:00:26 Job 'j-25081423220749979514c392aefb5eb4': created (progress 0%)
# 0:00:34 Job 'j-25081423220749979514c392aefb5eb4': created (progress 0%)
# 0:00:44 Job 'j-25081423220749979514c392aefb5eb4': created (progress 0%)
# 0:00:56 Job 'j-25081423220749979514c392aefb5eb4': created (progress 0%)
# 0:01:12 Job 'j-25081423220749979514c392aefb5eb4': error (progress N/A)
# Your batch job 'j-25081423220749979514c392aefb5eb4' failed. Error logs:
# [{'id': '[1755213768157, 535603]', 'time': '2025-08-14T23:22:48.157Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-25081423220749979514c392aefb5eb4" and returned 0 results.'}, {'id': '[1755213768904, 109106]', 'time': '2025-08-14T23:22:48.904Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-25081423220749979514c392aefb5eb4" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-25081423220749979514c392aefb5eb4').logs()`.
# [SKIP] Amatitlán 2025-07-10 -> Batch job 'j-25081423220749979514c392aefb5eb4' didn't finish successfully. Status: error (after 0:01:12).
# 0:00:00 Job 'j-2508142323214f8583b93eda25b09115': send 'start'
# 0:00:13 Job 'j-2508142323214f8583b93eda25b09115': created (progress 0%)
# 0:00:19 Job 'j-2508142323214f8583b93eda25b09115': created (progress 0%)
# 0:00:25 Job 'j-2508142323214f8583b93eda25b09115': created (progress 0%)
# 0:00:33 Job 'j-2508142323214f8583b93eda25b09115': created (progress 0%)
# 0:00:43 Job 'j-2508142323214f8583b93eda25b09115': created (progress 0%)
# 0:00:56 Job 'j-2508142323214f8583b93eda25b09115': running (progress N/A)
# 0:01:12 Job 'j-2508142323214f8583b93eda25b09115': running (progress N/A)
# 0:01:31 Job 'j-2508142323214f8583b93eda25b09115': running (progress N/A)
# 0:01:55 Job 'j-2508142323214f8583b93eda25b09115': running (progress N/A)
# 0:02:25 Job 'j-2508142323214f8583b93eda25b09115': running (progress N/A)
# 0:03:03 Job 'j-2508142323214f8583b93eda25b09115': finished (progress 100%)
# [OK] Atitlán 2025-07-17
# 0:00:00 Job 'j-2508142327444b0da58421d6ad1b16b9': send 'start'
# 0:00:13 Job 'j-2508142327444b0da58421d6ad1b16b9': created (progress 0%)
# 0:00:18 Job 'j-2508142327444b0da58421d6ad1b16b9': created (progress 0%)
# 0:00:25 Job 'j-2508142327444b0da58421d6ad1b16b9': running (progress N/A)
# 0:00:33 Job 'j-2508142327444b0da58421d6ad1b16b9': running (progress N/A)
# 0:00:43 Job 'j-2508142327444b0da58421d6ad1b16b9': running (progress N/A)
# 0:00:56 Job 'j-2508142327444b0da58421d6ad1b16b9': running (progress N/A)
# 0:01:12 Job 'j-2508142327444b0da58421d6ad1b16b9': running (progress N/A)
# 0:01:31 Job 'j-2508142327444b0da58421d6ad1b16b9': finished (progress 100%)
# [OK] Amatitlán 2025-07-17
# 0:00:00 Job 'j-25081423293543f681a18fd4f906ebd9': send 'start'
# 0:00:13 Job 'j-25081423293543f681a18fd4f906ebd9': created (progress 0%)
# 0:00:18 Job 'j-25081423293543f681a18fd4f906ebd9': created (progress 0%)
# 0:00:25 Job 'j-25081423293543f681a18fd4f906ebd9': created (progress 0%)
# 0:00:33 Job 'j-25081423293543f681a18fd4f906ebd9': created (progress 0%)
# 0:00:43 Job 'j-25081423293543f681a18fd4f906ebd9': running (progress N/A)
# 0:00:56 Job 'j-25081423293543f681a18fd4f906ebd9': running (progress N/A)
# 0:01:11 Job 'j-25081423293543f681a18fd4f906ebd9': running (progress N/A)
# 0:01:31 Job 'j-25081423293543f681a18fd4f906ebd9': running (progress N/A)
# 0:01:55 Job 'j-25081423293543f681a18fd4f906ebd9': running (progress N/A)
# 0:05:39 Job 'j-25081423293543f681a18fd4f906ebd9': finished (progress 100%)
# [OK] Atitlán 2025-07-20
# 0:00:00 Job 'j-25081423365244cab2064aa9ff9eeaba': send 'start'
# 0:00:13 Job 'j-25081423365244cab2064aa9ff9eeaba': created (progress 0%)
# 0:00:18 Job 'j-25081423365244cab2064aa9ff9eeaba': queued (progress 0%)
# 0:00:25 Job 'j-25081423365244cab2064aa9ff9eeaba': queued (progress 0%)
# 0:00:33 Job 'j-25081423365244cab2064aa9ff9eeaba': queued (progress 0%)
# 0:00:43 Job 'j-25081423365244cab2064aa9ff9eeaba': queued (progress 0%)
# 0:00:56 Job 'j-25081423365244cab2064aa9ff9eeaba': queued (progress 0%)
# 0:01:12 Job 'j-25081423365244cab2064aa9ff9eeaba': queued (progress 0%)
# 0:01:31 Job 'j-25081423365244cab2064aa9ff9eeaba': error (progress N/A)
# Your batch job 'j-25081423365244cab2064aa9ff9eeaba' failed. Error logs:
# [{'id': '[1755214657442, 598218]', 'time': '2025-08-14T23:37:37.442Z', 'level': 'error', 'message': 'create_pyramid failed: Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-25081423365244cab2064aa9ff9eeaba" and returned 0 results.'}, {'id': '[1755214658134, 199172]', 'time': '2025-08-14T23:37:38.134Z', 'level': 'error', 'message': 'OpenEO batch job failed: OpenEOApiException(status_code=400, code=\'NoDataAvailable\', message=\'There is no data available for the given extents. Could not find data for your load_collection request with catalog ID "Sentinel2". The catalog query had correlation ID "j-25081423365244cab2064aa9ff9eeaba" and returned 0 results.\', id=\'no-request\')'}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-25081423365244cab2064aa9ff9eeaba').logs()`.
# [SKIP] Amatitlán 2025-07-20 -> Batch job 'j-25081423365244cab2064aa9ff9eeaba' didn't finish successfully. Status: error (after 0:01:31).
# 0:00:00 Job 'j-2508142338244e39a4531773ea034179': send 'start'
# 0:00:13 Job 'j-2508142338244e39a4531773ea034179': created (progress 0%)
# 0:00:19 Job 'j-2508142338244e39a4531773ea034179': created (progress 0%)
# 0:00:25 Job 'j-2508142338244e39a4531773ea034179': created (progress 0%)
# 0:00:33 Job 'j-2508142338244e39a4531773ea034179': created (progress 0%)
# 0:00:43 Job 'j-2508142338244e39a4531773ea034179': created (progress 0%)
# 0:00:56 Job 'j-2508142338244e39a4531773ea034179': running (progress N/A)
# 0:01:12 Job 'j-2508142338244e39a4531773ea034179': running (progress N/A)
# 0:01:31 Job 'j-2508142338244e39a4531773ea034179': running (progress N/A)
# 0:01:55 Job 'j-2508142338244e39a4531773ea034179': finished (progress 100%)
# [OK] Atitlán 2025-07-24
# 0:00:00 Job 'j-2508142342414b79975e7a7c6d5ba381': send 'start'
# 0:00:13 Job 'j-2508142342414b79975e7a7c6d5ba381': created (progress 0%)
# 0:00:18 Job 'j-2508142342414b79975e7a7c6d5ba381': created (progress 0%)
# 0:00:24 Job 'j-2508142342414b79975e7a7c6d5ba381': created (progress 0%)
# 0:00:33 Job 'j-2508142342414b79975e7a7c6d5ba381': running (progress N/A)
# 0:00:43 Job 'j-2508142342414b79975e7a7c6d5ba381': running (progress N/A)
# 0:00:55 Job 'j-2508142342414b79975e7a7c6d5ba381': running (progress N/A)
# 0:01:11 Job 'j-2508142342414b79975e7a7c6d5ba381': running (progress N/A)
# 0:01:30 Job 'j-2508142342414b79975e7a7c6d5ba381': running (progress N/A)
# 0:01:54 Job 'j-2508142342414b79975e7a7c6d5ba381': running (progress N/A)
# 0:02:25 Job 'j-2508142342414b79975e7a7c6d5ba381': running (progress N/A)
# 0:03:02 Job 'j-2508142342414b79975e7a7c6d5ba381': finished (progress 100%)
# [OK] Amatitlán 2025-07-24
# 0:00:00 Job 'j-250814234610498b9ba1c10bdd4973e3': send 'start'
# 0:00:13 Job 'j-250814234610498b9ba1c10bdd4973e3': created (progress 0%)
# 0:00:19 Job 'j-250814234610498b9ba1c10bdd4973e3': created (progress 0%)
# 0:00:25 Job 'j-250814234610498b9ba1c10bdd4973e3': created (progress 0%)
# 0:00:34 Job 'j-250814234610498b9ba1c10bdd4973e3': created (progress 0%)
# 0:00:44 Job 'j-250814234610498b9ba1c10bdd4973e3': created (progress 0%)
# 0:00:56 Job 'j-250814234610498b9ba1c10bdd4973e3': created (progress 0%)
# 0:01:12 Job 'j-250814234610498b9ba1c10bdd4973e3': running (progress N/A)
# 0:01:31 Job 'j-250814234610498b9ba1c10bdd4973e3': running (progress N/A)
# 0:01:55 Job 'j-250814234610498b9ba1c10bdd4973e3': running (progress N/A)
# 0:02:25 Job 'j-250814234610498b9ba1c10bdd4973e3': finished (progress 100%)
# [OK] Atitlán 2025-08-01
# 0:00:00 Job 'j-25081423505042e29b2c84ccc281ffa1': send 'start'
# 0:00:13 Job 'j-25081423505042e29b2c84ccc281ffa1': created (progress 0%)
# 0:00:19 Job 'j-25081423505042e29b2c84ccc281ffa1': running (progress N/A)
# 0:00:25 Job 'j-25081423505042e29b2c84ccc281ffa1': running (progress N/A)
# 0:00:33 Job 'j-25081423505042e29b2c84ccc281ffa1': running (progress N/A)
# 0:00:43 Job 'j-25081423505042e29b2c84ccc281ffa1': running (progress N/A)
# 0:00:56 Job 'j-25081423505042e29b2c84ccc281ffa1': running (progress N/A)
# 0:01:12 Job 'j-25081423505042e29b2c84ccc281ffa1': running (progress N/A)
# 0:01:31 Job 'j-25081423505042e29b2c84ccc281ffa1': running (progress N/A)
# 0:01:55 Job 'j-25081423505042e29b2c84ccc281ffa1': running (progress N/A)
# 0:02:25 Job 'j-25081423505042e29b2c84ccc281ffa1': finished (progress 100%)
# [OK] Amatitlán 2025-08-01
#          date       lake    chl_mean  chl_median     chl_p25     chl_p75
# 0  2025-02-07    Atitlán   42.474064   20.899792   10.655164   42.604095
# 1  2025-02-07  Amatitlán  111.009659  102.274704   86.056862  128.964249
# 2  2025-02-10    Atitlán    8.951129    7.584282    6.286437   10.782980
# 3  2025-02-25    Atitlán   16.665104   16.988651   14.829579   18.736156
# 4  2025-02-27    Atitlán   16.134600   15.959796   14.462414   17.727194
# 5  2025-02-27  Amatitlán   75.908188   80.717224   50.323441  102.759125
# 6  2025-03-02    Atitlán   19.695658   14.375379    9.183393   21.819719
# 7  2025-03-04    Atitlán   15.603611   15.709960   13.897983   17.441000
# 8  2025-03-04  Amatitlán  148.569138  135.697815  105.180649  187.255478
# 9  2025-03-07    Atitlán   27.255985   14.942939    8.907138   19.900459
# 10 2025-03-09    Atitlán   16.127670   16.059505   14.652471   17.441000
# 11 2025-03-09  Amatitlán   80.804680   76.534973   33.167000  114.473541
# 12 2025-03-12    Atitlán   18.076473   18.358418   17.313911   19.134983
# 13 2025-03-14    Atitlán   15.084842   15.166773   13.353731   16.902559
# 14 2025-03-14  Amatitlán   42.758610   25.630741   12.786452   63.615009
# 15 2025-03-19    Atitlán   16.639273   16.258530   14.516137   18.835876
# 16 2025-03-19  Amatitlán   97.783066   87.301384   55.636509  136.494537
# 17 2025-03-22    Atitlán   34.567196   15.849171    6.361275   23.401766
# 18 2025-03-24    Atitlán   14.726792   14.808676   13.176892   16.333027
# 19 2025-03-24  Amatitlán  133.852081  129.935257   95.159241  171.080338
# 20 2025-03-26    Atitlán   18.956591   18.292027   14.856938   22.405844
# 21 2025-03-26  Amatitlán    8.757950    6.472064    5.404735    9.057765
# 22 2025-04-03    Atitlán   19.720371   18.024237   15.124022   21.006872
# 23 2025-04-03  Amatitlán  117.379951  106.609726   67.244522  163.607834
# 24 2025-04-11    Atitlán   19.794094   18.666367   17.542553   19.783953
# 25 2025-04-13    Atitlán   14.852129   14.948350   13.309664   16.509163
# 26 2025-04-13  Amatitlán   41.187031   40.545376   31.258484   52.345413
# 27 2025-04-15    Atitlán   16.150330   15.889829   13.430143   18.497236
# 28 2025-04-15  Amatitlán   54.072948   53.796299   42.036659   64.297935
# 29 2025-04-16    Atitlán    5.002104    4.321159    3.060915    5.948010
# 30 2025-04-18    Atitlán   15.202677   14.925467   12.284577   17.441000
# 31 2025-04-18  Amatitlán   46.242699   47.513844   38.272831   54.640194
# 32 2025-04-28    Atitlán   16.212154   15.884929   13.402095   18.601820
# 33 2025-04-28  Amatitlán   82.388184   75.672081   60.372730   97.713188
# 34 2025-05-03    Atitlán   17.278091   17.294853   15.878346   18.566788
# 35 2025-05-03  Amatitlán   53.084122   44.101723   32.403786   64.643921
# 36 2025-05-13    Atitlán   16.317308   16.312717   14.128665   18.470726
# 37 2025-05-13  Amatitlán   54.973164   47.643581   35.997604   69.009033
# 38 2025-05-28    Atitlán   17.945114   18.070267   16.352499   19.092461
# 39 2025-05-28  Amatitlán   44.910675   45.091431   35.291840   53.633751
# 40 2025-07-10    Atitlán   20.579908   17.869049   13.129575   25.207355
# 41 2025-07-17    Atitlán   20.035818   17.441000   12.588929   23.489008
# 42 2025-07-17  Amatitlán   43.474697   41.163662   28.599298   53.848839
# 43 2025-07-20    Atitlán    5.354540    4.112646    3.011243    6.299232
# 44 2025-07-24    Atitlán   19.397848   18.099087   13.967817   23.000540
# 45 2025-07-24  Amatitlán   56.531525   52.310543   40.829388   69.227936
# 46 2025-08-01    Atitlán   15.540994   13.662868   10.685042   18.041311
# 47 2025-08-01  Amatitlán   31.316437   19.329630   15.201732   31.399710
# Actualizado data/chl_timeseries.csv → total filas: 50
